# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-01-30 20:37:39  | Have a great day.
# ...

# %%
_,_,_ = WPEM.XRDSimulation(filepath='PbSO4.cif',two_theta_range=(10, 80, 0.01))
# Out:
# the space group of input crystal is : P n m a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 26 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 8.55 5.28 6.73 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Pb2+', 'O2-', 2.3251]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='PbSO4.cif',two_theta_range=(10, 80, 0.01),GrainSize=3,)
# Out:
# the space group of input crystal is : P n m a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 26 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 8.55 5.28 6.73 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Pb2+', 'O2-', 2.3251]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='PbSO4.cif',two_theta_range=(10, 80, 0.01),GrainSize=3,orientation=[0.3, 0.3],thermo_vib=0.2,zero_shift=1.2)
# Out:
# the space group of input crystal is : P n m a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 26 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 8.55 5.28 6.73 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Pb2+', 'O2-', 2.3251]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='PbSO4.cif',two_theta_range=(10, 80, 0.01),GrainSize=3,bacI=True,orientation=[0.3, 0.3],thermo_vib=0.2,zero_shift=1)
# Out:
# the space group of input crystal is : P n m a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 26 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 8.55 5.28 6.73 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Pb2+', 'O2-', 2.3251]
# XRD simulation process of WPEM is completed !
